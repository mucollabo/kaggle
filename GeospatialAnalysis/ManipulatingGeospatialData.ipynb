# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
from folium import Marker
import warnings
warnings.filterwarnings('ignore')

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent='kaggle_learn')
location = geolocator.geocode('Pyramid of Khufu')

print(location.point)
print(location.address)
# Out:
# 29 58m 44.9927s N, 31 8m 3.16774s E
# هرم خوفو, شارع ابو الهول السياحي, كوم الأخضر, الجيزة, 12125, مصر

# %%
point = location.point
print('Latitude:', point.latitude)
print('Longitude:', point.longitude)
# Out:
# Latitude: 29.97916465
# Longitude: 31.13421326082681

# %%
universities = pd.read_csv('./input/geospatial-learn-course-data/top_universities.csv')
universities.head()
# Out:
#                       Name
# 0     University of Oxford
# 1  University of Cambridge
# 2  Imperial College London
# 3               ETH Zurich
# 4                      UCL

# %%
def my_geocoder(row):
    try:
        point = geolocator.geocode(row).point
        return pd.Series({'Latitude': point.latitude, 'Longitude': point.longitude})
    except:
        return None

universities[['Latitude', 'Longitude']] = universities.apply(lambda x: my_geocoder(x['Name']), axis=1)

print("{}% of address were geocoded!".format(
    (1 - sum(np.isnan(universities['Latitude'])) / len(universities)) * 100))

# Drop universities that were not successfully geocoded
universities = universities.loc[~np.isnan(universities["Latitude"])]
universities = gpd.GeoDataFrame(universities, geometry=gpd.points_from_xy(universities.Longitude, universities.Latitude))
universities.crs = {'init': 'epsg:4326'}
universities.head()
# Out:
# 90.0% of address were geocoded!
#                       Name   Latitude  Longitude                   geometry
# 0     University of Oxford  51.758708  -1.255668  POINT (-1.25567 51.75871)
# 1  University of Cambridge  52.210946   0.092005   POINT (0.09200 52.21095)
# 2  Imperial College London  51.498959  -0.175641  POINT (-0.17564 51.49896)
# 3               ETH Zurich  47.413218   8.537491   POINT (8.53749 47.41322)
# 4                      UCL  51.521785  -0.135151  POINT (-0.13515 51.52179)

# %%
# Create a map
m = folium.Map(location=[54, 15], tiles='openstreetmap', zoom_start=2)

# Add points to the map
for idx, row in universities.iterrows():
    Marker([row['Latitude'], row['Longitude']], popup=row['Name']).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_214925f1e79cdf0f0d96e410d4bd5115 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_214925f1e79cdf0f0d96e410d4bd5115&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_214925f1e79cdf0f0d96e410d4bd5115 = L.map(
#                 &quot;map_214925f1e79cdf0f0d96e410d4bd5115&quot;,
#                 {
#                     center: [54.0, 15.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_04a10be19d44d55d1b9aae32a26ff929 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_04a10be19d44d55d1b9aae32a26ff929.addTo(map_214925f1e79cdf0f0d96e410d4bd5115);
#
#
#             var marker_fa5f61b8d17515a34370d91bc7d374c9 = L.marker(
#                 [51.75870755, -1.2556684826092037],
#                 {}
#             ).addTo(map_214925f1e79cdf0f0d96e410d4bd5115);
#
#
#         var popup_e72ff1e582135ee3e96c019937a88197 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3cb92bbcf74bb8d017f65701fd6830b5 = $(`&lt;div id=&quot;html_3cb92bbcf74bb8d017f65701fd6830b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University of Oxford&lt;/div&gt;`)[0];
#                 popup_e72ff1e582135ee3e96c019937a88197.setContent(html_3cb92bbcf74bb8d017f65701fd6830b5);
#
#
#
#         marker_fa5f61b8d17515a34370d91bc7d374c9.bindPopup(popup_e72ff1e582135ee3e96c019937a88197)
#         ;
#
#
#
#
#             var marker_bdba1d474ab723cf22a71ae1455be774 = L.marker(
#                 [52.210945550000005, 0.09200497637871279],
#                 {}
#             ).addTo(map_214925f1e79cdf0f0d96e410d4bd5115);
#
#
#         var popup_ef41a7f2e395367fe84710008ed1f741 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d490f03cdede5573f8c6afbc4fcdb8f7 = $(`&lt;div id=&quot;html_d490f03cdede5573f8c6afbc4fcdb8f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University of Cambridge&lt;/div&gt;`)[0];
#                 popup_ef41a7f2e395367fe84710008ed1f741.setContent(html_d490f03cdede5573f8c6afbc4fcdb8f7);
#
#
#
#         marker_bdba1d474ab723cf22a71ae1455be774.bindPopup(popup_ef41a7f2e395367fe84710008ed1f741)
#         ;
#
#
#
#
#             var marker_668dd3c3ddc744487f1a1f05463c2503 = L.marker(
#                 [51.4989595, -0.17564069276310426],
#                 {}
#             ).addTo(map_214925f1e79cdf0f0d96e410d4bd5115);
#
#
#         var popup_d52a53c22b9752a5604655edcb2771cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b31e120231f035b2552e89f5f2b80da6 = $(`&lt;div id=&quot;html_b31e120231f035b2552e89f5f2b80da6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Imperial College London&lt;/div&gt;`)[0];
#                 popup_d52a53c22b9752a5604655edcb2771cd.setContent(html_b31e120231f035b2552e89f5f2b80da6);
#
#
#
#         marker_668dd3c3ddc744487f1a1f05463c2503.bindPopup(popup_d52a53c22b9752a5604655edcb2771cd)
#         ;
#
#
#
#
#             var marker_a856cb57645f2917dc4efb7006a4a7a8 = L.marker(
#                 [47.413218, 8.5374914],
#                 {}
#             ).addTo(map_214925f1e79cdf0f0d96e410d4bd5115);
#
#
#         var popup_0e63aaaa1f985b639d011cfb26c9a0c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ab57038183cfab333b9adf20f76b66ba = $(`&lt;div id=&quot;html_ab57038183cfab333b9adf20f76b66ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ETH Zurich&lt;/div&gt;`)[0];
#                 popup_0e63aaaa1f985b639d011cfb26c9a0c6.setContent(html_ab57038183cfab333b9adf20f76b66ba);
#
#
#
#         marker_a856cb57645f2917dc4efb7006a4a7a8.bindPopup(popup_0e63aaaa1f985b639d011cfb26c9a0c6)
#         ;
#
#
#
#
#             var marker_dc9f9f1486a75b3dafb4e273957f13dc = L.marker(
#                 [51.5217852, -0.13515149671251314],
#                 {}
#             ).addTo(map_214925f1e79cdf0f0d96e410d4bd5115);
#
#
#         var popup_e528c0e5f36b2149f7006d4a00f8b6e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12349cde2e5ffde7acbd70dac728aadf = $(`&lt;div id=&quot;html_12349cde2e5ffde7acbd70dac728aadf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UCL&lt;/div&gt;`)[0];
#                 popup_e528c0e5f36b2149f7006d4a00f8b6e4.setContent(html_12349cde2e5ffde7acbd70dac728aadf);
#
#
#
#         marker_dc9f9f1486a75b3dafb4e273957f13dc.bindPopup(popup_e528c0e5f36b2149f7006d4a00f8b6e4)
#         ;
#
#
#
#
#             var marker_712c31defb3e2d649026ae89f074b3b2 = L.marker(
#                 [51.51426105, -0.11673351981492822],

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
europe = world.loc[world.continent == 'Europe'].reset_index(drop=True)

europe_stats = europe[['name', 'pop_est', 'gdp_md_est']]
europe_boundaries = europe[['name', 'geometry']]

# %%
europe_boundaries.head()
# Out:
#       name                                           geometry
# 0   Russia  MULTIPOLYGON (((180.00000 71.51571, 180.00000 ...
# 1   Norway  MULTIPOLYGON (((15.14282 79.67431, 15.52255 80...
# 2   France  MULTIPOLYGON (((-51.65780 4.15623, -52.24934 3...
# 3   Sweden  POLYGON ((11.02737 58.85615, 11.46827 59.43239...
# 4  Belarus  POLYGON ((28.17671 56.16913, 29.22951 55.91834...

# %%
europe_stats.head()
# Out:
#       name      pop_est  gdp_md_est
# 0   Russia  144373535.0     1699876
# 1   Norway    5347896.0      403336
# 2   France   67059887.0     2715518
# 3   Sweden   10285453.0      530883
# 4  Belarus    9466856.0       63080

# %%
# Use an attribute join to merge data about countries in Europe
europe = europe_boundaries.merge(europe_stats, on='name')
europe.head()
# Out:
#       name                                           geometry      pop_est  \
# 0   Russia  MULTIPOLYGON (((180.00000 71.51571, 180.00000 ...  144373535.0
# 1   Norway  MULTIPOLYGON (((15.14282 79.67431, 15.52255 80...    5347896.0
# 2   France  MULTIPOLYGON (((-51.65780 4.15623, -52.24934 3...   67059887.0
# 3   Sweden  POLYGON ((11.02737 58.85615, 11.46827 59.43239...   10285453.0
# 4  Belarus  POLYGON ((28.17671 56.16913, 29.22951 55.91834...    9466856.0
#
#    gdp_md_est
# 0     1699876
# 1      403336
# 2     2715518
# 3      530883
# 4       63080

# %%
# Use spatial join to match universities to countries in Europe
european_universities = gpd.sjoin(universities, europe)

# Investigate the result
print("We located {} universites.".format(len(universities)))
print("Only {} of the universities were located in Europe (in {} different countries).".format(len(european_universities), len(european_universities.name.unique())))

european_universities.head()
# Out:
# We located 90 universites.
# Only 88 of the universities were located in Europe (in 15 different countries).
#                                                Name   Latitude  Longitude  \
# 0                              University of Oxford  51.758708  -1.255668
# 1                           University of Cambridge  52.210946   0.092005
# 2                           Imperial College London  51.498959  -0.175641
# 4                                               UCL  51.521785  -0.135151
# 5  London School of Economics and Political Science  51.514261  -0.116734
#
#                     geometry  index_right            name     pop_est  \
# 0  POINT (-1.25567 51.75871)           28  United Kingdom  66834405.0
# 1   POINT (0.09200 52.21095)           28  United Kingdom  66834405.0
# 2  POINT (-0.17564 51.49896)           28  United Kingdom  66834405.0
# 4  POINT (-0.13515 51.52179)           28  United Kingdom  66834405.0
# 5  POINT (-0.11673 51.51426)           28  United Kingdom  66834405.0
#
#    gdp_md_est
# 0     2829108
# 1     2829108
# 2     2829108
# 4     2829108
# 5     2829108
