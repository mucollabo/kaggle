# %%
import pandas as pd
import geopandas as gpd
import math

# %%
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster

# %%
# Create a map
m_1 = folium.Map(location=[42.32,-71.0589], tiles='openstreetmap', zoom_start=11)

# Display the map
m_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9e0fb87565783be487323887d9a15cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9e0fb87565783be487323887d9a15cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9e0fb87565783be487323887d9a15cb = L.map(
#                 &quot;map_f9e0fb87565783be487323887d9a15cb&quot;,
#                 {
#                     center: [42.32, -71.0589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ebd3a668b282d221110866420050b18 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6ebd3a668b282d221110866420050b18.addTo(map_f9e0fb87565783be487323887d9a15cb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Load the data
crimes = pd.read_csv("./data/crimes-in-boston/crimes-in-boston/crime.csv", encoding='latin-1')

# Drop rows with missing locations
crimes.dropna(subset = ['Lat', 'Long', 'DISTRICT'], inplace=True)

# Focus on major crimes on 2018
crimes = crimes[crimes.OFFENSE_CODE_GROUP.isin(['Larceny', 'Auto Theft', 'Robbery', 'Larceny From Motor Vehicle', 'Residential Burglary',
    'Simple Assault', 'Harassment', 'Ballistics', 'Aggravated Assault', 'Other Burglary', 
    'Arson', 'Commercial Burglary', 'HOME INVASION', 'Homicide', 'Criminal Harassment', 
    'Manslaughter'])]

crimes = crimes[crimes.YEAR >= 2018]

crimes.head()
# Out:
#    INCIDENT_NUMBER  OFFENSE_CODE          OFFENSE_CODE_GROUP  \
# 0       I182070945           619                     Larceny
# 6       I182070933           724                  Auto Theft
# 8       I182070931           301                     Robbery
# 19      I182070915           614  Larceny From Motor Vehicle
# 24      I182070908           522        Residential Burglary
#
#                       OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0                      LARCENY ALL OTHERS      D14            808      NaN
# 6                              AUTO THEFT       B2            330      NaN
# 8                        ROBBERY - STREET       C6            177      NaN
# 19  LARCENY THEFT FROM MV - NON-ACCESSORY       B2            181      NaN
# 24      BURGLARY - RESIDENTIAL - NO FORCE       B2            911      NaN
#
#        OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  UCR_PART  \
# 0   2018-09-02 13:00:00  2018      9      Sunday    13  Part One
# 6   2018-09-03 21:25:00  2018      9      Monday    21  Part One
# 8   2018-09-03 20:48:00  2018      9      Monday    20  Part One
# 19  2018-09-02 18:00:00  2018      9      Sunday    18  Part One
# 24  2018-09-03 18:38:00  2018      9      Monday    18  Part One
#
#                STREET        Lat       Long                     Location
# 0          LINCOLN ST  42.357791 -71.139371  (42.35779134, -71.13937053)
# 6         NORMANDY ST  42.306072 -71.082733  (42.30607218, -71.08273260)
# 8   MASSACHUSETTS AVE  42.331521 -71.070853  (42.33152148, -71.07085307)
# 19         SHIRLEY ST  42.325695 -71.068168  (42.32569490, -71.06816778)
# 24    ANNUNCIATION RD  42.335062 -71.093168  (42.33506218, -71.09316781)

# %%
daytime_robberies = crimes[((crimes.OFFENSE_CODE_GROUP == 'Robbery') & (crimes.HOUR.isin(range(9, 18))))]

# %%
# Create a map
m_2 = folium.Map(location=[42.32,-71.0589], tiles='cartodbpositron', zoom_start=13)

# Add points to the map
for idx, row in daytime_robberies.iterrows():
    Marker([row['Lat'], row['Long']]).add_to(m_2)
m_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21e8d7a3dd82064ccc13941e3a52ea81 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21e8d7a3dd82064ccc13941e3a52ea81&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21e8d7a3dd82064ccc13941e3a52ea81 = L.map(
#                 &quot;map_21e8d7a3dd82064ccc13941e3a52ea81&quot;,
#                 {
#                     center: [42.32, -71.0589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3dff300358cb5694ea2fc05c2569ee18 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3dff300358cb5694ea2fc05c2569ee18.addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_3edcd23e3fba46dd179281e922926301 = L.marker(
#                 [42.37167264, -71.06326413],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_7b1e8eb561223ca85918277ce41e809f = L.marker(
#                 [42.27645319, -71.11297971],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_61cbcfecc7b7ce7257a8308ddd7b05cd = L.marker(
#                 [42.3460551, -71.07050669],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_2698cab7c74eaaa39b44f0186caa94b0 = L.marker(
#                 [42.36219081, -71.06223802],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_940b68d141810bf221b4b6c0586dc13f = L.marker(
#                 [42.33153805, -71.08015661],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_40434e427a7b63f6b5f563e19cabd4c8 = L.marker(
#                 [42.30492239, -71.10298073],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_bf8def290d2b5b458bcff7c140b439e9 = L.marker(
#                 [42.32624204, -71.10317575],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_5ce1680d039292a9d3ff672955ef6619 = L.marker(
#                 [42.24894017, -71.12130622],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_fe32676de1be3020a2f028d9cc706420 = L.marker(
#                 [42.332354, -71.07138696],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_503bf12a4156ed41c485532332e49ec9 = L.marker(
#                 [42.29623685, -71.04853645],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_55945f5e615bda2b9df1dcabd0233de4 = L.marker(
#                 [42.35521625, -71.06012863],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_083b13d4cf0b4746c349c1f03f54f8e5 = L.marker(
#                 [42.3524587, -71.13762608],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_3a102d9e8ec1bab1cb4e561ddad9f38f = L.marker(
#                 [42.32277007, -71.10445458],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_a7338572034aae9f96463cced3619e75 = L.marker(
#                 [42.35327561, -71.06345772],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_52cf9d675260057d9b7767acdb0dadc4 = L.marker(
#                 [42.35602373, -71.06177615],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_676a4a7d28740cf0432dcaebc2d4d3f4 = L.marker(
#                 [42.35331987, -71.06102314],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_a203d756e870d9e6ed2bf05e01658250 = L.marker(
#                 [42.2752767, -71.09554245],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_3c0a796fff53b477a3b570330ac36316 = L.marker(
#                 [42.30803768, -71.08359213],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_aa4ff8771ef72a1f1ba3368e17acf1b0 = L.marker(
#                 [42.35218278, -71.0556788],
#                 {}
#             ).addTo(map_21e8d7a3dd82064ccc13941e3a52ea81);
#
#
#             var marker_d5ef1b4aecdf1c0623564ecec2a0ab9a = L.marker(
#                 [42.35255981, -71.06043207],
#                 {}
#             ).addTo(map_

# %%
# Create a map
m_3 = folium.Map(location=[42.32,-71.0589], tiles='cartodbpositron', zoom_start=13)

# Add points to the map
mc = MarkerCluster()
for idx, row in daytime_robberies.iterrows():
    if not math.isnan(row['Long']) and not math.isnan(row['Lat']):
        mc.add_child(Marker([row['Lat'], row['Long']]))
        
m_3.add_child(mc)

# Display the map
m_3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7b9945e05e235cfea0b55c04801b021 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7b9945e05e235cfea0b55c04801b021&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d7b9945e05e235cfea0b55c04801b021 = L.map(
#                 &quot;map_d7b9945e05e235cfea0b55c04801b021&quot;,
#                 {
#                     center: [42.32, -71.0589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9965a0f96683dcd230890c2a5acef921 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9965a0f96683dcd230890c2a5acef921.addTo(map_d7b9945e05e235cfea0b55c04801b021);
#
#
#             var marker_cluster_c4709e1124188774c1b13718a4e4e072 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_190b5a5384d817d55247ae773005b6d7 = L.marker(
#                 [42.37167264, -71.06326413],
#                 {}
#             ).addTo(marker_cluster_c4709e1124188774c1b13718a4e4e072);
#
#
#             var marker_7c642793a4e4973f2d27cc40a6c07e90 = L.marker(
#                 [42.27645319, -71.11297971],
#                 {}
#             ).addTo(marker_cluster_c4709e1124188774c1b13718a4e4e072);
#
#
#             var marker_c8eb8d5642b26bc37d66eed6a77f037e = L.marker(
#                 [42.3460551, -71.07050669],
#                 {}
#             ).addTo(marker_cluster_c4709e1124188774c1b13718a4e4e072);
#
#
#             var marker_d328e71439c8e1d1eb511801e622ef3c = L.marker(
#                 [42.36219081, -71.06223802],
#                 {}
#             ).addTo(marker_cluster_c4709e1124188774c1b13718a4e4e072);
#
#
#             var marker_266e5b0e6a8e8e058c977d108763f2dd = L.marker(
#                 [42.33153805, -71.08015661],
#                 {}
#             ).addTo(marker_cluster_c4709e1124188774c1b13718a4e4e072);
#
#
#             var marker_f199d2ab505d651da393ebf3a1f6a2b4 = L.marker(
#                 [42.30492239, -71.10298073],
#                 {}
#             ).addTo(marker_cluster_c4709e1124188774c1b13718a4e4e072);
#
#
#             var marker_98fcd80d97dcca07470a5e0a8a661d0f = L.marker(
#                 [42.32624204, -71.10317575],
#                 {}
#             ).addTo(marker_cluster_c4709e1124188774c1b13718a4e4e072);
#
#
#             var marker_4d8f9119ef4516a84cff74df3cf40d88 = L.marker(
#                 [42.24894017, -71.12130622],
#                 {}
#             ).addTo(marker_cluster_c4709e1124188774c1b13718a4e4e072);
#
#
#             var marker_85547c7b9d1117fe02057b931a489486 = L.marker(
#                 [42.332354, -71.07138696],
#                 {}
#             ).addTo(marker_cluster_c4709e1124188774c1b13718a4e4e072);
#
#
#             var marker_35d19fdd105aef191275045be7500c82 = L.marker(
#                 [42.29623685, -71.04853645],
#                 {}
#             ).addTo(marker_cluster_c4709e1124188774c1b13718a4e4e072);
#
#
#             var marker_d23f32416dfa8e12276332e5d57c25c9 = L.marker(
#                 [42.35521625, -71.06012863],
#                 {}
#             ).addTo(marker_cluster_c4709e1124188774c1b13718a4e4e072);
#
#
#             var marker_dca8bef5259e3c154f126c47b9a88e33 = L.marker(
#                 [42.3524587, -71.13762608],
#                 {}
#             ).addTo(marker_cluster_c4709e1124188774c1b13718a4e4e072);
#
#
#             var marker_146fd00d0c3b60a495569dcaba4d07a2 = L.marker(
#                 [42.32277007, -71.10445458],
#                 {}
#             ).addTo(marker_cluster_c4709e1124188774c1b13718a4e4e072);
#
#
#             var marker_04de30d28559c5004193419818ea4a14 = L.marker(
#                 [42.35327561, -71.06345772],
#                 {}
#             ).addTo(marker_cluster_c4709e1124188774c1b13718a4e4e072);
#
#
#             var marker_f22e75e0c637299ff8e12a7a737b0d0b = L.marker(
#                 [42.35602373, -71.06177615],
#                 {}
#             ).addTo(marker_cluster_c4709e1124188774c1b13718a4e4e072);
#
#
#             var marker_ea9c042d69daaa8c1ae96dac67d4563f = L.marker(
#                 [42.35331987, -71.06102314],
#                 {}
#             ).addTo(marker_cluster_c4709e1124188774c1b13718a4e4e072);
#
#
#             v
